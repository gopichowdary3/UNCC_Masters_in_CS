# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/drive/MyDrive/NLP/tweets1.csv')

# %%
df1.shape
# Out:
# (413, 4)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/NLP/tweetsclog1.csv')

# %%
df2.shape
# Out:
# (293, 4)

# %%
frames = [df1, df2]
  
result = pd.concat(frames)
result.shape
# Out:
# (706, 4)

# %%
result
# Out:
#                       id                                               text  \
# 0    1653217200587825153  Get online class homework, assignment, exam he...
# 1    1653216999122812929  Need online class help? We are available to he...
# 2    1653216967594246145  Get online class homework, assignment and exam...
# 3    1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4    1652779924518850560  Looking for some spring apparel? Make sure to ...
# ..                   ...                                                ...
# 288  1653121366952910856  Solar racking in place. Tomorrow the panels go...
# 289  1653121156029771777  Northwest winds gusting 40+mph and freshly plo...
# 290  1653120532114550784  🚨🇺🇸 #BREAKING: Multiple injuries reported afte...
# 291  1653118756824948747  2025 Kenwood - Aleks Alston @alston_aleks pick...
# 292  1653118137980813312  @amaury_wiggins @CoachOatesOL @Coach_BMiller @...
#
#                 user                 created_at
# ...

# %%
result.reset_index(inplace=True, drop=True)

# %%
result
# Out:
#                       id                                               text  \
# 0    1653217200587825153  Get online class homework, assignment, exam he...
# 1    1653216999122812929  Need online class help? We are available to he...
# 2    1653216967594246145  Get online class homework, assignment and exam...
# 3    1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4    1652779924518850560  Looking for some spring apparel? Make sure to ...
# ..                   ...                                                ...
# 701  1653121366952910856  Solar racking in place. Tomorrow the panels go...
# 702  1653121156029771777  Northwest winds gusting 40+mph and freshly plo...
# 703  1653120532114550784  🚨🇺🇸 #BREAKING: Multiple injuries reported afte...
# 704  1653118756824948747  2025 Kenwood - Aleks Alston @alston_aleks pick...
# 705  1653118137980813312  @amaury_wiggins @CoachOatesOL @Coach_BMiller @...
#
#                 user                 created_at
# ...

# %%
df = result.drop_duplicates(['text'])

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#                       id                                               text  \
# 0    1653217200587825153  Get online class homework, assignment, exam he...
# 1    1653216999122812929  Need online class help? We are available to he...
# 2    1653216967594246145  Get online class homework, assignment and exam...
# 3    1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4    1652779924518850560  Looking for some spring apparel? Make sure to ...
# ..                   ...                                                ...
# 428  1653121366952910856  Solar racking in place. Tomorrow the panels go...
# 429  1653121156029771777  Northwest winds gusting 40+mph and freshly plo...
# 430  1653120532114550784  🚨🇺🇸 #BREAKING: Multiple injuries reported afte...
# 431  1653118756824948747  2025 Kenwood - Aleks Alston @alston_aleks pick...
# 432  1653118137980813312  @amaury_wiggins @CoachOatesOL @Coach_BMiller @...
#
#                 user                 created_at
# ...

# %%
#Perform k-fold cross-validation to select the optimal value of k for feature selection
k_scores = []
for k in range(100 0, 12866, 1000):
    selector = SelectKBest(score_func=chi2, k=k)
    X_new = selector.fit_transform(tfidf_df, tweet_sentiment)
    model = LogisticRegression()
    scores = cross_val_score(model, X_new, tweet_sentiment, cv=10)
    k_scores.append((k, scores.mean(), scores.std()))

# %%
from textblob import TextBlob
 def get_tweet_sentiment(tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        blob_tweet = TextBlob((tweet))
        # set sentiment
        if blob_tweet.sentiment.polarity > 0:
            return 'positive'
        elif blob_tweet.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
