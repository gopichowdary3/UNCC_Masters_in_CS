# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
df1 = pd.read_excel('/content/gdrive/MyDrive/IV_midterm/1 SDOH_2013_Codebook_1_0.xlsx')
df2 = pd.read_excel('/content/gdrive/MyDrive/IV_midterm/2 SDOH_2013_COUNTY_1_0.xlsx')
df3 = pd.read_excel('/content/gdrive/MyDrive/IV_midterm/3 SDOH_2013_ZIPCODE_1_0.xlsx')
df4 = pd.read_excel('/content/gdrive/MyDrive/IV_midterm/4 sdoh_2013_tract_1_0.xlsx')

# %%
df1.head(20)
# Out:
#    SDOH Database 2013 Codebook Summary & Introduction
# 0                        Purpose of the SDOH Database
# 1   Incorporating SDOH data into research that sup...
# 2                Purpose and Contents of the Codebook
# 3   This variable codebook was developed to provid...
# 4   The fields contained in the county, ZIP Code, ...
# 5   Domain: Variables in the SDOH Database were se...
# 6   SDOH Topic Area: For each domain, there are 1 ...
# 7   Variable Name: The variable name as it appears...
# 8   Variable Label: A descriptive label for the va...
# 9   Data Source: The original source of the variab...
# 10  Type of Data: The variable type (numeric or ch...
# 11  SAS Length: The variable’s SAS length as it ap...
# 12  SAS Character: The variable’s SAS character as...
# 13  Position in the file: The variable’s position ...
# 14  The fields contained in the County-SUMMARY, ZI...
# 15  Descriptive statistics for continuous variable...
# ...

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68302b2f4bd0> in <module>
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
df3.head(20)
# Out:
#                                 name  \
# 0                               YEAR
# 1                          STATEFIPS
# 2                            ZIPCODE
# 3                               ZCTA
# 4                              STATE
# 5                             REGION
# 6                          TERRITORY
# 7                          POINT_ZIP
# 8                  ACS_TOT_POP_WT_ZC
# 9           ACS_TOT_POP_US_ABOVE1_ZC
# 10             ACS_TOT_POP_ABOVE5_ZC
# 11            ACS_TOT_POP_ABOVE15_ZC
# 12            ACS_TOT_POP_ABOVE16_ZC
# 13              ACS_TOT_POP_16_19_ZC
# 14            ACS_TOT_POP_ABOVE25_ZC
# 15      ACS_TOT_CIVIL_POP_ABOVE18_ZC
# 16  ACS_TOT_CIVIL_VET_POP_ABOVE25_ZC
# 17      ACS_TOT_OWN_CHILD_BELOW17_ZC
# 18            ACS_TOT_WORKER_NWFH_ZC
# 19              ACS_TOT_WORKER_HH_ZC
#
#                                                 label  type  length format
# 0                                      SDOH file year   num       4     4.
# ...

# %%
df4.head(320)
# Out:
#                           name  \
# 0                         YEAR
# 1                    TRACTFIPS
# 2                   COUNTYFIPS
# 3                    STATEFIPS
# 4                        STATE
# ..                         ...
# 305     POS_DIST_PED_ICU_TRACT
# 306  POS_DIST_OBSTETRICS_TRACT
# 307      POS_DIST_CLINIC_TRACT
# 308         POS_DIST_ALC_TRACT
# 309            CEN_AIAN_NH_IND
#
#                                                  label  type  length format
# 0                                       SDOH file year   num       3     4.
# 1       State-county-census tract FIPS Code (11-digit)  char      11   $11.
# 2                     State-county FIPS Code (5-digit)  char       5    $5.
# 3                            State FIPS Code (2-digit)  char       2    $2.
# 4                                           State name  char      25   $25.
# ..                                                 ...   ...     ...    ...
# ...

# %%
df2020tract.head(1000)
# Out:
#                           name  \
# 0                         YEAR
# 1                    TRACTFIPS
# 2                   COUNTYFIPS
# 3                    STATEFIPS
# 4                        STATE
# ..                         ...
# 324     POS_DIST_PED_ICU_TRACT
# 325  POS_DIST_OBSTETRICS_TRACT
# 326      POS_DIST_CLINIC_TRACT
# 327         POS_DIST_ALC_TRACT
# 328            CEN_AIAN_NH_IND
#
#                                                  label  type  length format
# 0                                       SDOH file year   num       3     4.
# 1       State-county-census tract FIPS Code (11-digit)  char      11   $11.
# 2                     State-county FIPS Code (5-digit)  char       5    $5.
# 3                            State FIPS Code (2-digit)  char       2    $2.
# 4                                           State name  char      25   $25.
# ..                                                 ...   ...     ...    ...
# ...

# %%
x= ['gopi', 'suji', 'triveni']
y=dict(enumerate(x))
y
# Out:
# {0: 'gopi', 1: 'suji', 2: 'triveni'}

# %%
import numpy as np 
from tensorflow import keras
int_sequence = np.arange(20)
dummy_dataset = keras.utils.timeseries_dataset_from_array(
 data=int_sequence[1:], 
 targets=int_sequence[:-6],
 sequence_length=5,
 batch_size=2, 
)
for inputs, targets in dummy_dataset:
    for i in range(inputs.shape[0]):
        print([int(x) for x in inputs[i]], int(targets[i]))
# Out:
# [1, 2, 3, 4, 5] 0
# [2, 3, 4, 5, 6] 1
# [3, 4, 5, 6, 7] 2
# [4, 5, 6, 7, 8] 3
# [5, 6, 7, 8, 9] 4
# [6, 7, 8, 9, 10] 5
# [7, 8, 9, 10, 11] 6
# [8, 9, 10, 11, 12] 7
# [9, 10, 11, 12, 13] 8
# [10, 11, 12, 13, 14] 9
# [11, 12, 13, 14, 15] 10
# [12, 13, 14, 15, 16] 11
# [13, 14, 15, 16, 17] 12
# [14, 15, 16, 17, 18] 13
