# %%
import tweepy
import pandas as pd

# Set up API keys and access tokens
API_Key = 'BSFgXqbHXlF3GHBqqaZTKu0T8'
API_Key_Secret = 'JWfisUdgN6uc6NQiA2RLZeMllOxJ6VJrNrYL8cJ51snUonUTK6'
Access_Token = '1653095657861701634-ZsXlIaEypQYwCKTZ0gcS8g40oDbBAi'
Access_Token_Secret = 'tdhUqXE1dZxLr2qz5ms5hEhCHhns9pkvpGry7cV0glYfF'

# Authenticate with the Twitter API
authorize = tweepy.OAuthHandler(API_Key, API_Key_Secret)
authorize.set_access_token(Access_Token, Access_Token_Secret)
api = tweepy.API(authorize)

# Define the hashtag to search for
hashtagList = ['#UofIllinois', '#UIC', '#ILLINOIS', 'IllinoisLibrary', '#Illini']

# Define the universities to search for
universities = ['University of Illinois']

# Create an empty list to store tweets
tweets = []

# Search for tweets containing the hashtags
for university in universities:
    for hashtag in hashtagList:
        query = hashtag
        searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(1500)
        for tweet in searched_tweets:
            if 'retweeted_status' in tweet._json:
                continue
            if tweet not in tweets:
                tweets.append(tweet)

# Convert tweets to a DataFrame
df = pd.DataFrame({
    'id': [tweet.id_str for tweet in tweets],
    'text': [tweet.full_text for tweet in tweets],
    'user': [tweet.user.screen_name for tweet in tweets],
    'created_at': [tweet.created_at for tweet in tweets],
})

# Write DataFrame to CSV file
df.to_csv('tweets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-1-ff89980c0078> in <cell line: 25>()
#      27         query = hashtag
#      28         searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(1500)
# ---> 29         for tweet in searched_tweets:
#      30             if 'retweeted_status' in tweet._json:
#      31                 continue
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1307         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1308         """
# -> 1309         return self.request(
#    1310             'GET', 'search/tweets', endpoint_parameters=(
#    1311                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267                 raise NotFound(resp)
#     268             if resp.status_code == 429:
# --> 269                 raise TooManyRequests(resp)
#     270             if resp.status_code >= 500:
#     271                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
len(tweets)
# Out:
# 390

# %%
# Convert tweets to a DataFrame
df = pd.DataFrame({
    'id': [tweet.id_str for tweet in tweets],
    'text': [tweet.full_text for tweet in tweets],
    'user': [tweet.user.screen_name for tweet in tweets],
    'created_at': [tweet.created_at for tweet in tweets],
})

# Write DataFrame to CSV file
df.to_csv('tweets.csv', index=False)

from google.colab import files
files.download('tweets.csv')

# %%
hashtagList = ['IllinoisLibrary', '#UofIllinois', '#UIC', '#ILLINOIS']
for hashtag in hashtagList:
    query = hashtag
    searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(1500)
    for tweet in searched_tweets:
        if 'retweeted_status' in tweet._json:
            continue
        if tweet not in tweets:
            tweets.append(tweet)

# %%
len(tweets)
# Out:
# 393

# %%
hashtagList = ['#Illini','#IllinoisLibrary', '#UofIllinois', '#UIC', '#ILLINOIS']
for university in universities:
    for hashtag in hashtagList:
        query = university + ' ' + hashtag
        searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(1500)
        for tweet in searched_tweets:
            if 'retweeted_status' in tweet._json:
                continue
            if tweet not in tweets:
                tweets.append(tweet)

# %%
len(tweets)
# Out:
# 411

# %%
hashtagList = ['#UniversityofIllinois', '#UofIllinois', '#Illini','#IllinoisLibrary', '#UIC', '#ILLINOIS']
for university in universities:
    for hashtag in hashtagList:
        query = university + ' ' + hashtag
        # Define the maximum number of tweets to retrieve
        max_tweets = 40000

        # Define the number of tweets to retrieve per page
        tweets_per_page = 1000
        # Loop through search results using pagination
        for page in tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').pages(max_tweets // tweets_per_page):
        # Loop through tweets on the page
            for tweet in page:
            # Check if the tweet is a retweet or a duplicate
                if 'retweeted_status' in tweet._json:
                    continue
                if tweet not in tweets:
                    tweets.append(tweet)

# %%
# Convert tweets to a DataFrame
df1 = pd.DataFrame({
    'id': [tweet.id_str for tweet in tweets],
    'text': [tweet.full_text for tweet in tweets],
    'user': [tweet.user.screen_name for tweet in tweets],
    'created_at': [tweet.created_at for tweet in tweets],
})

# Write DataFrame to CSV file
df1.to_csv('tweets1.csv', index=False)

from google.colab import files
files.download('tweets1.csv')

# %%
df1
# Out:
#                       id                                               text  \
# 0    1653217200587825153  Get online class homework, assignment, exam he...
# 1    1653216999122812929  Need online class help? We are available to he...
# 2    1653216967594246145  Get online class homework, assignment and exam...
# 3    1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4    1652779924518850560  Looking for some spring apparel? Make sure to ...
# ..                   ...                                                ...
# 408  1650539669644357644  Check out why Anushka Waikar chose to pursue h...
# 409  1650445505493864448  Heartiest congratulations to Ms. Deepanshu (ht...
# 410  1649808997099134979  Was chosen to present at the Military History ...
# 411  1652107543861239808  NPR Illinois can't freely report on faculty #s...
# 412  1651247688229216264  with a concentration in Dietetics from the Uni...
#
#                 user                created_at
# 0           HwExpert 2023-05-02 01:57:50+00:00
# 1           HwExpert 2023-05-02 01:57:02+00:00
# 2           HwExpert 2023-05-02 01:56:55+00:00
# 3    PlatosChampaign 2023-04-30 23:00:15+00:00
# 4    PlatosChampaign 2023-04-30 21:00:15+00:00
# ..               ...                       ...
# 408      IllinoisPSM 2023-04-24 16:38:17+00:00
# 409           IITPAT 2023-04-24 10:24:06+00:00
# 410  WilderHistorian 2023-04-22 16:14:51+00:00
# 411      paulinepark 2023-04-29 00:28:27+00:00
# 412        mysteamid 2023-04-26 15:31:42+00:00
#
# [413 rows x 4 columns]

# %%
hashtagList = ['#UniversityofIllinois', '#IllinoisLibrary', '#Illini', '#UofIllinois','#ILLINOIS', '#UIC']
for university in universities:
    for hashtag in hashtagList:
        query = hashtag
        searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(15000)
        for tweet in searched_tweets:
            if 'retweeted_status' in tweet._json:
                continue
            if tweet not in tweets:
                tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-48-4bc2c09fae6f> in <cell line: 2>()
#       4         query = hashtag
#       5         searched_tweets = tweepy.Cursor(api.search_tweets, q=query, lang='en', tweet_mode='extended').items(15000)
# ----> 6         for tweet in searched_tweets:
#       7             if 'retweeted_status' in tweet._json:
#       8                 continue
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1307         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1308         """
# -> 1309         return self.request(
#    1310             'GET', 'search/tweets', endpoint_parameters=(
#    1311                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267                 raise NotFound(resp)
#     268             if resp.status_code == 429:
# --> 269                 raise TooManyRequests(resp)
#     270             if resp.status_code >= 500:
#     271                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
len(tweets)
# Out:
# 583

# %%
# Convert tweets to a DataFrame
df2 = pd.DataFrame({
    'id': [tweet.id_str for tweet in tweets],
    'text': [tweet.full_text for tweet in tweets],
    'user': [tweet.user.screen_name for tweet in tweets],
    'created_at': [tweet.created_at for tweet in tweets],
})

# Write DataFrame to CSV file
df2.to_csv('tweets583.csv', index=False)

from google.colab import files
files.download('tweets583.csv')

# %%
hashtagList = ['#UniversityofIllinois', '#IllinoisLibrary', '#Illini', '#UofIllinois','#ILLINOIS', '#UIC']
for university in universities:
    for hashtag in hashtagList:
        query = hashtag
        year = 2022
        searched_tweets = tweepy.Cursor(api.search_tweets, q=query , lang='en', tweet_mode='extended').items(15000)
        for tweet in searched_tweets:
            if 'retweeted_status' in tweet._json:
                continue
            if tweet not in tweets:
                tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-72-05f7fac89fca> in <cell line: 2>()
#       5         year = 2022
#       6         searched_tweets = tweepy.Cursor(api.search_tweets, q=query , lang='en', tweet_mode='extended').items(15000)
# ----> 7         for tweet in searched_tweets:
#       8             if 'retweeted_status' in tweet._json:
#       9                 continue
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1307         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1308         """
# -> 1309         return self.request(
#    1310             'GET', 'search/tweets', endpoint_parameters=(
#    1311                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267                 raise NotFound(resp)
#     268             if resp.status_code == 429:
# --> 269                 raise TooManyRequests(resp)
#     270             if resp.status_code >= 500:
#     271                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
hashtagList = ['#UniversityofIllinois','#UofIllinois',  '#Illini','#IllinoisLibrary', '#UIC', '#ILLINOIS']
for university in universities:
    for hashtag in hashtagList:
        query = hashtag

        # Define the date range to search for tweets
        since_date = '2022-01-01'
        until_date = '2022-12-31'
        # Define the maximum number of tweets to retrieve
        max_tweets = 1500

        # Define the number of tweets to retrieve per page
        tweets_per_page = 100
        # Loop through search results using pagination
        for page in tweepy.Cursor(api.search_tweets, q=hashtag, lang='en', tweet_mode='extended',count =100).pages(200):
        # Loop through tweets on the page
            for tweet in page:
            # Check if the tweet is a retweet or a duplicate
                if 'retweeted_status' in tweet._json:
                    continue
                if tweet not in tweets:
                    tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-82-b984415e45f8> in <cell line: 2>()
#      13         tweets_per_page = 100
#      14         # Loop through search results using pagination
# ---> 15         for page in tweepy.Cursor(api.search_tweets, q=hashtag, lang='en', tweet_mode='extended',count =100).pages(200):
#      16         # Loop through tweets on the page
#      17             for tweet in page:
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.10/dist-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1307         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1308         """
# -> 1309         return self.request(
#    1310             'GET', 'search/tweets', endpoint_parameters=(
#    1311                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267                 raise NotFound(resp)
#     268             if resp.status_code == 429:
# --> 269                 raise TooManyRequests(resp)
#     270             if resp.status_code >= 500:
#     271                 raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
len(tweets)
# Out:
# 1085

# %%
# Convert tweets to a DataFrame
df3 = pd.DataFrame({
    'id': [tweet.id_str for tweet in tweets],
    'text': [tweet.full_text for tweet in tweets],
    'user': [tweet.user.screen_name for tweet in tweets],
    'created_at': [tweet.created_at for tweet in tweets],
})

# Write DataFrame to CSV file
df3.to_csv('tweets1085.csv', index=False)

from google.colab import files
files.download('tweets1085.csv')

# %%
df3
# Out:
#                        id                                               text  \
# 0     1653217200587825153  Get online class homework, assignment, exam he...
# 1     1653216999122812929  Need online class help? We are available to he...
# 2     1653216967594246145  Get online class homework, assignment and exam...
# 3     1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4     1652779924518850560  Looking for some spring apparel? Make sure to ...
# ...                   ...                                                ...
# 1080  1652508983683366947  @ReallyAmerican1 @SpeakerWelchIL Leads to foll...
# 1081  1652508098442002432  EPA's Eye In The Sky: #Joliet, #Illinois, #USA...
# 1082  1652504802323046400  Kennedy Blades blowing the doors off the GOAT,...
# 1083  1652496230126084097  State police checkpoint on 87th. Go to @Chicag...
# 1084  1652491456244858881  @fox32news Attention: #BOLO for #Missing 15yr ...
#
#                  user                created_at
# 0            HwExpert 2023-05-02 01:57:50+00:00
# 1            HwExpert 2023-05-02 01:57:02+00:00
# 2            HwExpert 2023-05-02 01:56:55+00:00
# 3     PlatosChampaign 2023-04-30 23:00:15+00:00
# 4     PlatosChampaign 2023-04-30 21:00:15+00:00
# ...               ...                       ...
# 1080  QueenBe74558749 2023-04-30 03:03:38+00:00
# 1081   CDNewsDispatch 2023-04-30 03:00:07+00:00
# 1082       1990AO1974 2023-04-30 02:47:01+00:00
# 1083  PharaohSaidThat 2023-04-30 02:12:57+00:00
# 1084      TheJoker128 2023-04-30 01:53:59+00:00
#
# [1085 rows x 4 columns]

# %%
len(tweets)
# Out:
# 1085

# %%
df2.drop_duplicates(subset=['text'])
# Out:
#                       id                                               text  \
# 0    1653217200587825153  Get online class homework, assignment, exam he...
# 1    1653216999122812929  Need online class help? We are available to he...
# 2    1653216967594246145  Get online class homework, assignment and exam...
# 3    1652810122521878530  We’ve got plenty of Illini gear! Feel free to ...
# 4    1652779924518850560  Looking for some spring apparel? Make sure to ...
# ..                   ...                                                ...
# 572  1652387558628761606  Awesome. Awesome awesome awesome. #illini http...
# 573  1652387278642364416  B4 | 🚨 @BrodyHarding2 web gem 🚨\n\n#Illini 3, ...
# 574  1652387173344108545  Buckeyes take the doubles point.\n\nOrder of f...
# 575  1652387062740398080  Sydney Brown to the Eagles\nChase Brown to the...
# 576  1652386845135712258  M3 | Three up, three down.\n\n#Illini 1, Penn ...
#
#                 user                created_at
# 0           HwExpert 2023-05-02 01:57:50+00:00
# 1           HwExpert 2023-05-02 01:57:02+00:00
# 2           HwExpert 2023-05-02 01:56:55+00:00
# 3    PlatosChampaign 2023-04-30 23:00:15+00:00
# 4    PlatosChampaign 2023-04-30 21:00:15+00:00
# ..               ...                       ...
# 572           fulknA 2023-04-29 19:01:08+00:00
# 573   IlliniBaseball 2023-04-29 19:00:01+00:00
# 574    IlliniWTennis 2023-04-29 18:59:36+00:00
# 575       mrwagner25 2023-04-29 18:59:10+00:00
# 576         IlliniSB 2023-04-29 18:58:18+00:00
#
# [576 rows x 4 columns]

# %%
import tweepy

# %%
client = tweepy.Client(bearer_token='REPLACE_ME')



# Replace with time period of your choice
start_time = '2020-01-01T00:00:00Z'

# Replace with time period of your choice
end_time = '2020-08-01T00:00:00Z'

searched_tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                  start_time=start_time,
                                  end_time=end_time, max_results=1500)
for tweet in searched_tweets:
            if 'retweeted_status' in tweet._json:
                continue
            if tweet not in tweets:
                tweets.append(tweet)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# <ipython-input-69-651714117320> in <cell line: 11>()
#       9 end_time = '2020-08-01T00:00:00Z'
#      10
# ---> 11 searched_tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#      12                                   start_time=start_time,
#      13                                   end_time=end_time, max_results=1500)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in search_all_tweets(self, query, **params)
#    1161         """
#    1162         params["query"] = query
# -> 1163         return self._make_request(
#    1164             "GET", "/2/tweets/search/all", params=params,
#    1165             endpoint_parameters=(
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# --> 129         response = self.request(method, route, params=request_params,
#     130                                 json=json, user_auth=user_auth)
#     131
#
# /usr/local/lib/python3.10/dist-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#      96                 raise BadRequest(response)
#      97             if response.status_code == 401:
# ---> 98                 raise Unauthorized(response)
#      99             if response.status_code == 403:
#     100                 raise Forbidden(response)
#
# Unauthorized: 401 Unauthorized
# Unauthorized

# %%
import sys
username = sys.argv[1]
username
# Out:
# '-f'
